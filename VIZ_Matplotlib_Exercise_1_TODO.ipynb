# %% [markdown]
# <a href="https://colab.research.google.com/github/immune-institute/viz-matplotlib-exercise-1-todo/blob/main/VIZ_Matplotlib_Exercise_1_TODO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**BASIC PLOTTING**

# %% [markdown]
# ##**Initial Setup**

# %% [markdown]
# ###**EXERCISE 1**: *

# %% [markdown]
# Import matplotlib and numpy:

# %% [markdown]
# ##**Basic Plotting**

# %% [markdown]
# ###**EXERCISE 2**: *

# %% [markdown]
# Plot three different points at:
#
# 1.   (-4, -6)
# 2.   (7, 15)
# 3.   (3.5, 6)

# %% [markdown]
# ###**EXERCISE 3**: *

# %% [markdown]
# Plot the same three points as a single plot:

# %% [markdown]
# ###**EXERCISE 4**: *

# %% [markdown]
# Plot the same three points as a line:

# %% [markdown]
# ###**EXERCISE 5**: *

# %% [markdown]
# Plot the line $y=3x+2$ in the 0<x<100 interval.

# %% [markdown]
# ###**EXERCISE 6**: *

# %% [markdown]
# Plot the line $y=2x^2+x-3$ in the -50<x<50 interval

# %% [markdown]
# ###**EXERCISE 7**: **

# %% [markdown]
# Generate the plot shown below

# %% [markdown]
# ##**Plot customization**

# %% [markdown]
# ###**EXERCISE 8**: **

# %% [markdown]
# With provided data generate the plot shown on below figure:

# %%
x = np.arange(0., 5., 0.2)
r = x
s = x**2
t = x**3

# %% [markdown]
# ###**EXERCISE 9**: *

# %% [markdown]
# Add some textual information to the plot:

# %%
x = np.arange(0., 5., 0.2)
r = x
s = x**2
t = x**3

# %% [markdown]
# ###**EXERCISE 10**: *

# %% [markdown]
# Adapt plot limits:

# %%
x = np.arange(0., 5., 0.2)
r = x
s = x**2
t = x**3

# %% [markdown]
# ###**EXERCISE 11**: *

# %% [markdown]
# Add a thick orange grid to the plot:

# %%
x = np.arange(0., 5., 0.2)
r = x
s = x**2
t = x**3

# %% [markdown]
# ###**EXERCISE 12**: ***

# %% [markdown]
# Plot required data as shown below:
# >$y_1=x^3*e^{-x^2}$
#
# >$y_2=x^4*e^{-x^2}$
#
# >$y_3=x^5*e^{-x^2}$

# %%
#Generate data

# %%
#Plot data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   after removing the cwd from sys.path.

# %% [markdown]
# ##**Multiple axes**

# %% [markdown]
# ###**EXERCISE 13**: *

# %% [markdown]
# Generate a 2x3 grid of plots

# %% [markdown]
# ###**EXERCISE 14**: ***

# %% [markdown]
# Plot the following grid of plots where:

# %% [markdown]
# ###**EXERCISE 15**: **

# %% [markdown]
# Plot the following axeses:

# %% [markdown]
# ###**EXERCISE 16**: ***

# %% [markdown]
# Plot the following axeses with provided data:

# %%
x = np.arange(1,5,0.1)

r = x**3
s = x**5*np.exp(-x**2)
u = np.sin(x)
v = np.sqrt(x)

# %% [markdown]
# ##**Special Plot Types**

# %% [markdown]
# ###**EXERCISE 17**: *

# %% [markdown]
# Plot the following data as a bar plot, scatter plot and line plot:

# %%
#Data
names = ['a', 'b', 'c', 'd', 'e']
values = [5, 8, 3, 4, 7]

# %% [markdown]
# ###**EXERCISE 18**: ****

# %% [markdown]
# Using the data set available at [https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/wines.csv](https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/wines.csv) create the bar plot shown below:
